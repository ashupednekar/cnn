# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib

def make_soup(url):
	html = urlopen(url).read()
	return BeautifulSoup(html)

def get_images(url):
	soup = make_soup(url)
	#this makes a list of bs4 element tags
	images = [img for img in soup.findAll('img')]
	print (str(len(images)) + "images found.")
	print ('Downloading images to current working directory.')
	#compile our unicode list of image links
	image_links = [each.get('src') for each in images]
	for each in image_links:
		filename=each.split('/')[-1]
		urllib.request.urlretrieve(each, filename)
	return image_links

# %%
#Scraping acceptable images, say "Good-morning" images
get_images('https://www.sendscraps.com/good-morning-6.html')
# Out:
# c:\users\ashu\appdata\local\programs\python\python37-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\ashu\appdata\local\programs\python\python37-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# 120images found.
# Downloading images to current working directory.
# ['https://img1.sendscraps.com/se/008/072.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/073.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/074.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/062.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/063.gif',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/064.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/065.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/066.gif',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/067.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/068.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/069.gif',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/070.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/071.jpg',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/001.gif',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png',
#  'https://img1.sendscraps.com/se/008/002.gif',
#  'https://img1.sendscraps.com/se/img/facebook_42x42.png',
#  'https://img1.sendscraps.com/se/img/pinterest_42x42.png',
#  'https://img1.sendscraps.com/se/img/email_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/whatsapp_42x42.png',
#  'https://img1.sendscraps.com/se/img/fb-messenger_42x42.png',
#  'https://img1.sendscraps.com/se/img/download_42x42.png']
